# %%
### API KEY  - get a key!
##https://newsapi.org/

## Example URL
## https://newsapi.org/v2/everything?
## q=tesla&from=2021-05-20&sortBy=publishedAt&
## apiKey=YOUR KEY HERE


## What to import
import requests  ## for getting data from a server GET
import re   ## for regular expressions
import pandas as pd    ## for dataframes and related
from pandas import DataFrame

## To tokenize and vectorize text type data
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
import random as rd
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix
#from sklearn.naive_bayes import BernoulliNB
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn import tree

from sklearn.decomposition import LatentDirichletAllocation
import matplotlib.pyplot as plt
import numpy as np

from sklearn.metrics import silhouette_samples, silhouette_score
import sklearn
from sklearn.cluster import KMeans

from sklearn import preprocessing

import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
from sklearn.manifold import MDS
from mpl_toolkits.mplot3d import Axes3D
from scipy.cluster.hierarchy import ward, dendrogram

# %%
####################################
##
##  Step 1: Connect to the server
##          Send a query
##          Collect and clean the
##          results
####################################

####################################################
##In the following loop, we will query thenewsapi servers
##for all the topic names in the list
## We will then build a large csv file
## where each article is a row
##
## From there, we will convert this data
## into a labeled dataframe
## so we can train and then test our DT
## model
####################################################

####################################################
## Build the URL and GET the results
## NOTE: At the bottom of this code
## commented out, you will find a second
## method for doing the following. This is FYI.
####################################################

## TEST FIRST!
## We are about to build this URL:
# https://newsapi.org/v2/everything?apiKey=...


topics=["wildfire", "Heatwave", "Droughts"]

## topics needs to be a list of strings (words)
## Next, let's build the csv file
## first and add the column names
## Create a new csv file to save the headlines
filename="NewHeadlines_2.csv"
MyFILE=open(filename,"w")  # "a"  for append   "r" for read
## with open
### Place the column names in - write to the first row
WriteThis="LABEL,Date,Source,Title,Headline\n"
MyFILE.write(WriteThis)
MyFILE.close()

## CHeck it! Can you find this file?
#### --------------------> GATHER - CLEAN - CREATE FILE    
## RE: documentation and options
## https://newsapi.org/docs/endpoints/everything

endpoint="https://newsapi.org/v2/everything"

################# enter for loop to collect
################# data on three topics
#######################################

for topic in topics:
   
    ## Dictionary Structure
    URLPost = {'apiKey':'989ac094cb51435894b856652dfa6dd8',
               'q':topic,
               'language':'en'
    }

    response=requests.get(endpoint, URLPost)
    print(response)
    jsontxt = response.json()
    print(jsontxt)
    #####################################################
   
   
    ## Open the file for append
    MyFILE=open(filename, "a") ## "a" for append to add stuff
    LABEL=topic
    for items in jsontxt["articles"]:
        print(items, "\n\n\n")
                 
        #Author=items["author"]
        #Author=str(Author)
        #Author=Author.replace(',', '')
       
        Source=items["source"]["name"]
        print(Source)
       
        Date=items["publishedAt"]
        ##clean up the date
        NewDate=Date.split("T")
        Date=NewDate[0]
        print(Date)
## CLEAN the Title
        ##----------------------------------------------------------
        ##Replace punctuation with space
        # Accept one or more copies of punctuation        
        # plus zero or more copies of a space
        # and replace it with a single space
        Title=items["title"]
        Title=str(Title)
        #print(Title)
        Title=re.sub(r'[,.;@#?!&$\-\']+', ' ', str(Title), flags=re.IGNORECASE)
        Title=re.sub(' +', ' ', str(Title), flags=re.IGNORECASE)
        Title=re.sub(r'\"', ' ', str(Title), flags=re.IGNORECASE)
       
        # and replace it with a single space
        ## NOTE: Using the "^" on the inside of the [] means
        ## we want to look for any chars NOT a-z or A-Z and replace
        ## them with blank. This removes chars that should not be there.
        Title=re.sub(r'[^a-zA-Z]', " ", str(Title), flags=re.VERBOSE)
        Title=Title.replace(',', '')
        Title=' '.join(Title.split())
        Title=re.sub("\n|\r", "", Title)
        print(Title)
        ##----------------------------------------------------------
       
        Headline=items["description"]
        Headline=str(Headline)
        Headline=re.sub(r'[,.;@#?!&$\-\']+', ' ', Headline, flags=re.IGNORECASE)
        Headline=re.sub(' +', ' ', Headline, flags=re.IGNORECASE)
        Headline=re.sub(r'\"', ' ', Headline, flags=re.IGNORECASE)
        Headline=re.sub(r'[^a-zA-Z]', " ", Headline, flags=re.VERBOSE)
        ## Be sure there are no commas in the headlines or it will
        ## write poorly to a csv file....
        Headline=Headline.replace(',', '')
        Headline=' '.join(Headline.split())
        Headline=re.sub("\n|\r", "", Headline)
       
        ### AS AN OPTION - remove words of a given length............
        Headline = ' '.join([wd for wd in Headline.split() if len(wd)>3])
   
        #print("Author: ", Author, "\n")
        #print("Title: ", Title, "\n")
        #print("Headline News Item: ", Headline, "\n\n")
       
        #print(Author)
        print(Title)
        print(Headline)
       
        WriteThis=str(LABEL)+","+str(Date)+","+str(Source)+","+ str(Title) + "," + str(Headline) + "\n"
        print(WriteThis)
       
        MyFILE.write(WriteThis)
       
    ## CLOSE THE FILE
    MyFILE.close()
# Out:
# <Response [200]>
# {'status': 'ok', 'totalResults': 3381, 'articles': [{'source': {'id': None, 'name': 'Lifehacker.com'}, 'author': 'Elizabeth Yuko', 'title': 'Use This Phone Number to Find a Cooling Center Near You', 'description': 'We’re not even a full month into summer, and much of the United States has already dealt with record-setting heat—not to mention the intermittent wildfire smoke from Canada. Between climate change and El Niño, this type of weather is expected to get worse dur…', 'url': 'https://lifehacker.com/use-this-phone-number-to-find-a-cooling-center-near-you-1850641814', 'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/c3be8027600a57f72bc8352f391747a0.jpg', 'publishedAt': '2023-07-15T15:00:00Z', 'content': 'Were not even a full month into summer, and much of the United States has already dealt with record-setting heatnot to mention the intermittent wildfire smoke from Canada. Between climate change and … [+1728 chars]'}, {'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': None, 'title': 'Italy: Drone spots suspected wildfire arsonist', 'description': 'A man is detained in Italy after he was seen at the scene of a wildfire in Calabria.', 'url': 'https://www.bbc.co.uk/news/av/world-europe-66343164', 'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/160AF/production/_130578209_p0g3kd5k.jpg', 'publishedAt': '2023-07-28T17:21:56Z', 'content': 'A man has been detained after he was spotted by a drone near a recently started wildfire in Calabria, Italy.\r\nThe footage was released by authorities in the region, who said a number of recent wildfi… [+26 chars]'}, {'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': 'https://www.facebook.com/bbcnews', 'title': 'Canada wildfire: Firefighter dies tackling British Columbia blaze', 'description': 'An evacuation order is in place for towns near the US border as fires there swirl out of control.', 'url': 'https://www.bbc.co.uk/news/world-us-canada-66352768', 'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/20B0/production/_130586380_fb3709e46112dd712483e2bb6fc86bb810508c91.jpg', 'publishedAt': '2023-07-30T08:49:26Z', 'content': "A third firefighter has died in Canada while battling the country's worst wildfire season on record.\r\nAuthorities say the firefighter died tackling the Donnie Creek fire near Fort St John, in the wes… [+2069 chars]"}, {'source': {'id': 'google-news', 'name': 'Google News'}, 'author': None, 'title': 'Wildfire rages near Athens - Reuters', 'description': 'Wildfire rages near Athens\xa0\xa0Reuters', 'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMiTGh0dHBzOi8vd3d3LnJldXRlcnMuY29tL25ld3MvcGljdHVyZS93aWxkZmlyZS1yYWdlcy1uZWFyLWF0aGVucy1pZFVTUlRTTEo4Q0jSAQA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1', 'urlToImage': None, 'publishedAt': '2023-07-18T12:27:00Z', 'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'}, {'source': {'id': 'google-news', 'name': 'Google News'}, 'author': None, 'title': 'Jet2, TUI cancel flights to Rhodes because of wildfire - Reuters', 'description': 'Jet2, TUI cancel flights to Rhodes because of wildfire\xa0\xa0Reuters', 'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMiYGh0dHBzOi8vd3d3LnJldXRlcnMuY29tL3dvcmxkL2V1cm9wZS9qZXQyLXR1aS1jYW5jZWwtZmxpZ2h0cy1yaG9kZXMtYmVjYXVzZS13aWxkZmlyZS0yMDIzLTA3LTIzL9IBAA?oc%3D5%26hl%3Den-CA%26gl%3DCA%26ceid%3DCA:en&gl=FR&hl=en-CA&cm=2&pc=n&src=1', 'urlToImage': None, 'publishedAt': '2023-07-23T10:17:44Z', 'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'}, {'source': {'id': 'google- ...
# {'source': {'id': None, 'name': 'Lifehacker.com'}, 'author': 'Elizabeth Yuko', 'title': 'Use This Phone Number to Find a Cooling Center Near You', 'description': 'We’re not even a full month into summer, and much of the United States has already dealt with record-setting heat—not to mention the intermittent wildfire smoke from Canada. Between climate change and El Niño, this type of weather is expected to get worse dur…', 'url': 'https://lifehacker.com/use-this-phone-number-to-find-a-cooling-center-near-you-1850641814', 'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/c3be8027600a57f72bc8352f391747a0.jpg', 'publishedAt': '2023-07-15T15:00:00Z', 'content': 'Were not even a full month into summer, and much of the United States has already dealt with record-setting heatnot to mention the intermittent wildfire smoke from Canada. Between climate change and … [+1728 chars]'}
#
#
#
# Lifehacker.com
# 2023-07-15
# Use This Phone Number to Find a Cooling Center Near You
# Use This Phone Number to Find a Cooling Center Near You
# even full month into summer much United States already dealt with record setting heat mention intermittent wildfire smoke from Canada Between climate change this type weather expected worse
# wildfire,2023-07-15,Lifehacker.com,Use This Phone Number to Find a Cooling Center Near You,even full month into summer much United States already dealt with record setting heat mention intermittent wildfire smoke from Canada Between climate change this type weather expected worse
#
# {'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': None, 'title': 'Italy: Drone spots suspected wildfire arsonist', 'description': 'A man is detained in Italy after he was seen at the scene of a wildfire in Calabria.', 'url': 'https://www.bbc.co.uk/news/av/world-europe-66343164', 'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/160AF/production/_130578209_p0g3kd5k.jpg', 'publishedAt': '2023-07-28T17:21:56Z', 'content': 'A man has been detained after he was spotted by a drone near a recently started wildfire in Calabria, Italy.\r\nThe footage was released by authorities in the region, who said a number of recent wildfi… [+26 chars]'}
#
#
#
# BBC News
# 2023-07-28
# Italy Drone spots suspected wildfire arsonist
# Italy Drone spots suspected wildfire arsonist
# detained Italy after seen scene wildfire Calabria
# wildfire,2023-07-28,BBC News,Italy Drone spots suspected wildfire arsonist,detained Italy after seen scene wildfire Calabria
#
# {'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': 'https://www.facebook.com/bbcnews', 'title': 'Canada wildfire: Firefighter dies tackling British Columbia blaze', 'description': 'An evacuation order is in place for towns near the US border as fires there swirl out of control.', 'url': 'https://www.bbc.co.uk/news/world-us-canada-66352768', 'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/20B0/production/_130586380_fb3709e46112dd712483e2bb6fc86bb810508c91.jpg', 'publishedAt': '2023-07-30T08:49:26Z', 'content': "A third firefighter has died in Canada while battling the country's worst wildfire season on record.\r\nAuthorities say the firefighter died tackling the Donnie Creek fire near Fort St John, in the wes… [+2069 chars]"}
#
#
#
# BBC News
# 2023-07-30
# Canada wildfire Firefighter dies tackling British Columbia blaze
# Canada wildfire Firefighter dies tackling British Columbia blaze
# evacuation order place towns near border fires there swirl control
# wildfire,2023-07-30,BBC News,Canada wildfire Firefighter dies tackling British Columbia blaze,evacuation order place towns near border fires there swirl control
#
# {'source': {'id': 'google-news', 'name': 'Google News'}, 'author': None, 'title': 'Wildfire rages near Athens - Reuters', 'description': 'Wildfire rages near Athens\xa0\xa0Reuters', 'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMiTGh0dHBzOi8vd3d3LnJldXRlcnMuY29tL25ld3MvcGljdHVyZS93aWxkZmlyZS1yYWdlcy1uZWFyLWF0aGVucy1pZFVTUlRTTEo4Q0jSAQA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1', 'urlToImage': None, 'publishedAt': '2023-07-18T12:27:00Z', 'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'}
#
#
#
# Google News
# 2023-07-18
# Wildfire rages near Athens Reuters
# Wildfire rages near Athens Reuters
# Wildfire rages near Athens Reuters
# wildfire,2023-07-18,Google News,Wildfire rages near Athens Reuters,Wildfire rages near Athens Reuters
#
# {'source': {'id': 'google-news', 'name': 'Google News'}, 'author': None, 'title': 'Jet2, TUI cancel flights to Rhodes because of wildfire - Reuters', 'description': 'Jet2, TUI cancel flights to Rhodes because of wildfire\xa0\xa0Reuters', 'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMiYGh0dHBzOi8vd3d3LnJldXRlcnMuY29tL3dvcmxkL2V1cm9wZS9qZXQyLXR1aS1jYW5jZWwtZmxpZ2h0cy1yaG9kZXMtYmVjYXVzZS13aWxkZmlyZS0yMDIzLTA3LTIzL9IBAA?oc%3D5%26hl%3Den-CA%26gl%3DCA%26ceid%3DCA:en&gl=FR&hl=en-CA&cm=2&pc=n&src=1', 'urlToImage': None, 'publishedAt': '2023-07-23T10:17:44Z', 'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'}
#
#
#
# Google News
# 2023-07-23
# Jet TUI cancel flights to Rhodes because of wildfire Reuters
# Jet TUI cancel flights to Rhodes because of wildfire Reuters
# cancel flights Rhodes because wildfire Reuters
# wildfire,2023-07-23,Google News,Jet TUI cancel flights to Rhodes because of wildfire Reuters,cancel flights Rhodes because wildfire Reuters
#
# {'source': {'id': 'google-news', 'name': 'Google News'}, 'author': None, 'title': "Firefighter killed battling wildfire in Canada's Northwest Territories - Reuters", 'description': "Firefighter killed battling wildfire in Canada's Northwest Territories\xa0\xa0Reuters", 'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMidWh0dHBzOi8vd3d3LnJldXRlcnMuY29tL3dvcmxkL2FtZXJpY2FzL2ZpcmVmaWdodGVyLWtpbGxlZC1iYXR0bGluZy13aWxkZmlyZS1jYW5hZGFzLW5vcnRod2VzdC10ZXJyaXRvcmllcy0yMDIzLTA3LTE2L9IBAA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1', 'urlToImage': None, 'publishedAt': '2023-07-16T19:16:18Z', 'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'}
#
#
#
# Google News
# 2023-07-16
# Firefighter killed battling wildfire in Canada s Northwest Territories Reuters
# Firefighter killed battling wildfire in Canada s Northwest Territories Reuters
# Firefighter killed battling wildfire Canada Northwest Territories Reuters
# wildfire,2023-07-16,Google News,Firefighter killed battling wildfire in Canada s Northwest Territories Reuters,Firefighter killed battling wildfire Canada Northwest Territories Reuters
#
# {'source': {'id': 'google-news', 'name': 'Google News'}, 'author': None, 'title': 'Properties destroyed by B.C. wildfire north of Pemberton - CTV News Vancouver', 'description': '<ol><li>Properties destroyed by B.C. wildfire north of Pemberton\xa0\xa0CTV News Vancouver\r\n</li><li>Properties lost as latest B.C. wildfire forces urgent evacuations\xa0\xa0CBC.ca\r\n</li><li>Properties lost to Gun Lake wildfire north of Whistler\xa0\xa0CBC Vancouver\r\n</li><li>…', 'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMid2h0dHBzOi8vYmMuY3R2bmV3cy5jYS9ldmFjdWVlLWRlc2NyaWJlcy1hYnNvbHV0ZS10b3JuYWRvLW9mLWZpcmUtdGhhdC1kZXN0cm95ZWQtY2FiaW5zLW5vcnRoLW9mLXBlbWJlcnRvbi1iLWMtMS42NTAzNzE50gEA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1', 'urlToImage': None, 'publishedAt': '2023-08-03T01:35:31Z', 'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'}
#
#
#
# Google News
# 2023-08-03
# Properties destroyed by B C wildfire north of Pemberton CTV News Vancouver
# Properties destroyed by B C wildfire north of Pemberton CTV News Vancouver
# Properties destroyed wildfire north Pemberton News Vancouver Properties lost latest wildfire forces urgent evacuations Properties lost Lake wildfire north Whistler Vancouver
# wildfire,2023-08-03,Google News,Properties destroyed by B C wildfire north of Pemberton CTV News Vancouver,Properties destroyed wildfire north Pemberton News Vancouver Properties lost latest wildfire forces urgent evacuations Properties lost Lake wildfire north Whistler Vancouver
#
# {'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': None, 'title': 'Watch raging wildfires shut down Italian airport', 'description': 'Palermo’s international airport was shut down overnight as fires burned around its perimeter.', 'url': 'https://www.bbc.co.uk/news/av/world-europe-66298131', 'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/1B3A/production/_130507960_p0g2qsql.jpg', 'publishedAt': '2023-07-25T04:47:35Z', 'content': 'Palermos international airport was shut down overnight as fires burned around its perimeter. The wildfire is one of several on the island of Sicily and has spread due to windy conditions. \r\nSouthern … [+119 chars]'}
#
#
#
# BBC News
# 2023-07-25
# Watch raging wildfires shut down Italian airport
# Watch raging wildfires shut down Italian airport
# Palermo international airport shut down overnight fires burned around perimeter
# wildfire,2023-07-25,BBC News,Watch raging wildfires shut down Italian airport,Palermo international airport shut down overnight fires burned around perimeter
#
# {'source': {'id': 'google-news', 'name': 'Google News'}, 'author': None, 'title': 'Wildfire rages southeast of Greek capital, villagers told to evacuate - Reuters', 'description': 'Wildfire rages southeast of Greek capital, villagers told to evacuate\xa0\xa0Reuters', 'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMib2h0dHBzOi8vd3d3LnJldXRlcnMuY29tL3dvcmxkL2V1cm9wZS93aWxkZmlyZS1yYWdlcy1zb3V0aGVhc3QtZ3JlZWstY2FwaXRhbC12aWxsYWdlcnMtdG9sZC1ldmFjdWF0ZS0yMDIzLTA3LTE3L9IBAA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1', 'urlToImage': None, 'publishedAt': '2023-07-17T12:58:00Z', 'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'}
#
#
#
# Google News
# 2023-07-17
# Wildfire rages southeast of Greek capital villagers told to evacuate Reuters
# Wildfire rages southeast of Greek capital villagers told to evacuate Reuters
# Wildfire rages southeast Greek capital villagers told evacuate Reuters
# wildfire,2023-07-17,Google News,Wildfire rages southeast of Greek capital villagers told to evacuate Reuters,Wildfire rages southeast Greek capital villagers told evacuate Reuters
#
# {'source': {'id': 'google-news', 'name': 'Google News'}, 'author': None, 'title': 'Evacuation order issued for Canadian town as wildfire crosses over from US - Reuters', 'description': 'Evacuation order issued for Canadian town as wildfire crosses over from US\xa0\xa0Reuters', 'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMid2h0dHBzOi8vd3d3LnJldXRlcnMuY29tL2J1c2luZXNzL2Vudmlyb25tZW50L2V2YWN1YXRpb24tb3JkZXItaXNzdWVkLWNhbmFkaWFuLXRvd24td2lsZGZpcmUtY3Jvc3Nlcy1vdmVyLXVzLTIwMjMtMDctMzAv0gEA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1', 'urlToImage': None, 'publishedAt': '2023-07-30T08:14:00Z', 'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'}
#
#
#
# Google News
# 2023-07-30
# Evacuation order issued for Canadian town as wildfire crosses over from US Reuters
# Evacuation order issued for Canadian town as wildfire crosses over from US Reuters
# Evacuation order issued Canadian town wildfire crosses over from Reuters
# wildfire,2023-07-30,Google News,Evacuation order issued for Canadian town as wildfire crosses over from US Reuters,Evacuation order issued Canadian town wildfire crosses over from Reuters
#
# {'source': {'id': 'google-news', 'name': 'Google News'}, 'author': None, 'title': "Wildfire sets off landmines around Tehran's Evin prison, Iran's judiciary says - Reuters", 'description': "Wildfire sets off landmines around Tehran's Evin prison, Iran's judiciary says\xa0\xa0Reuters", 'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMigQFodHRwczovL3d3dy5yZXV0ZXJzLmNvbS93b3JsZC9taWRkbGUtZWFzdC93aWxkZmlyZS1zZXRzLW9mZi1sYW5kbWluZXMtYXJvdW5kLXRlaHJhbnMtZXZpbi1wcmlzb24taXJhbnMtanVkaWNpYXJ5LXNheXMtMjAyMy0wOC0wNC_SAQA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1', 'urlToImage': None, 'publishedAt': '2023-08-04T18:01:00Z', 'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'}
#
#
#
# Google News
# 2023-08-04
# Wildfire sets off landmines around Tehran s Evin prison Iran s judiciary says Reuters
# Wildfire sets off landmines around Tehran s Evin prison Iran s judiciary says Reuters
# Wildfire sets landmines around Tehran Evin prison Iran judiciary says Reuters
# wildfire,2023-08-04,Google News,Wildfire sets off landmines around Tehran s Evin prison Iran s judiciary says Reuters,Wildfire sets landmines around Tehran Evin prison Iran judiciary says Reuters
#
# {'source': {'id': 'google-news', 'name': 'Google News'}, 'author': None, 'title': 'Portugal wildfire rages as strong winds and heat fan flames - Reuters', 'description': 'Portugal wildfire rages as strong winds and heat fan flames\xa0\xa0Reuters', 'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMiZWh0dHBzOi8vd3d3LnJldXRlcnMuY29tL3dvcmxkL2V1cm9wZS9wb3J0dWdhbC13aWxkZmlyZS1yYWdlcy1zdHJvbmctd2luZHMtaGVhdC1mYW4tZmxhbWVzLTIwMjMtMDgtMDUv0gEA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1', 'urlToImage': None, 'publishedAt': '2023-08-05T15:43:00Z', 'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'}
#
#
#
# Google News
# 2023-08-05
# Portugal wildfire rages as strong winds and heat fan flames Reuters
# Portugal wildfire rages as strong winds and heat fan flames Reuters
# Portugal wildfire rages strong winds heat flames Reuters
# wildfire,2023-08-05,Google News,Portugal wildfire rages as strong winds and heat fan flames Reuters,Portugal wildfire rages strong winds heat flames Reuters
#
# {'source': {'id': 'google-news', 'name': 'Google News'}, 'author': None, 'title': 'Evacuation alert issued for Osoyoos after U.S. wildfire crosses border - Global News', 'description': '<ol><li>Evacuation alert issued for Osoyoos after U.S. wildfire crosses border\xa0\xa0Global News\r\n</li><li>Evacuation order issued for parts of Osoyoos as growing wildfire crosses Canada-U.S. border\xa0\xa0CBC.ca\r\n</li><li>Evacuation alert issued for parts of southern B…', 'url': 'https://consent.google.com/ml?continue=https://news.google.?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1', 'urlToImage': None, 'publishedAt': '2023-07-30T05:06:58Z', 'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'}
#
#
#
# Google News
# 2023-07-30
# Evacuation alert issued for Osoyoos after U S wildfire crosses border Global News
# Evacuation alert issued for Osoyoos after U S wildfire crosses border Global News
# Evacuation alert issued Osoyoos after wildfire crosses border Global News Evacuation order issued parts Osoyoos growing wildfire crosses Canada border Evacuation alert issued parts southern
# wildfire,2023-07-30,Google News,Evacuation alert issued for Osoyoos after U S wildfire crosses border Global News,Evacuation alert issued Osoyoos after wildfire crosses border Global News Evacuation order issued parts Osoyoos growing wildfire crosses Canada border Evacuation alert issued parts southern
#
# {'source': {'id': 'google-news', 'name': 'Google News'}, 'author': None, 'title': 'Canada wildfires: Firefighter killed in N.W.T. after sustaining injury on the job - CTV News', 'description': '<ol><li>Canada wildfires: Firefighter killed in N.W.T. after sustaining injury on the job\xa0\xa0CTV News\r\n</li><li>N.W.T. wildfire fighter dead after fire injury, officials say\xa0\xa0CBC News\r\n</li><li>Firefighter dead in Northwest Territories, 2nd killed in Canada thi…', 'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMic2h0dHBzOi8vd3d3LmN0dm5ld3MuY2EvY2xpbWF0ZS1hbmQtZW52aXJvbm1lbnQvYW5vdGhlci1jYW5hZGlhbi1maXJlZmlnaHRlci1raWxsZWQtb24td2lsZGZpcmUtZnJvbnRsaW5lcy0xLjY0ODE5NDXSAQA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1', 'urlToImage': None, 'publishedAt': '2023-07-16T19:37:00Z', 'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'}
#
#
#
# Google News
# 2023-07-16
# Canada wildfires Firefighter killed in N W T after sustaining injury on the job CTV News
# Canada wildfires Firefighter killed in N W T after sustaining injury on the job CTV News
# Canada wildfires Firefighter killed after sustaining injury News wildfire fighter dead after fire injury officials News Firefighter dead Northwest Territories killed Canada
# wildfire,2023-07-16,Google News,Canada wildfires Firefighter killed in N W T after sustaining injury on the job CTV News,Canada wildfires Firefighter killed after sustaining injury News wildfire fighter dead after fire injury officials News Firefighter dead Northwest Territories killed Canada
#
# {'source': {'id': 'google-news', 'name': 'Google News'}, 'author': None, 'title': "Behchokǫ̀ residents told to 'evacuate by tonight' over wildfire - Cabin Radio", 'description': '<ol><li>Behchokǫ̀ residents told to \'evacuate by tonight\' over wildfire\xa0\xa0Cabin Radio\r\n</li><li>Behchokǫ̀, N.W.T., ordered to evacuate due to wildfire burning nearby\xa0\xa0CBC.ca\r\n</li><li>Evacuation Alert - Electoral Area "I" (Blue Sky Country) - Stein Mountain Wi…', 'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMifWh0dHBzOi8vY2FiaW5yYWRpby5jYS8xMzcwNjcvbmV3cy9lbnZpcm9ubWVudC93aWxkZmlyZXMvYmVoY2hvayVDNyVBQi1yZXNpZGVudHMtYXJlLW9yZGVyZWQtdG8tbGVhdmUtY29tbXVuaXR5LW92ZXItd2lsZGZpcmUv0gEA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1', 'urlToImage': None, 'publishedAt': '2023-07-25T00:00:00Z', 'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'}
#
#
#
# Google News
# 2023-07-25
# Behchok residents told to evacuate by tonight over wildfire Cabin Radio
# Behchok residents told to evacuate by tonight over wildfire Cabin Radio
# Behchok residents told evacuate tonight over wildfire Cabin Radio Behchok ordered evacuate wildfire burning nearby Evacuation Alert Electoral Area Blue Country Stein Mountain
# wildfire,2023-07-25,Google News,Behchok residents told to evacuate by tonight over wildfire Cabin Radio,Behchok residents told evacuate tonight over wildfire Cabin Radio Behchok ordered evacuate wildfire burning nearby Evacuation Alert Electoral Area Blue Country Stein Mountain
#
# {'source': {'id': 'google-news', 'name': 'Google News'}, 'author': None, 'title': "BC Coroner issues safety alert over wildfire smoke after child's death - The Globe and Mail", 'description': "<ol><li>BC Coroner issues safety alert over wildfire smoke after child's death\xa0\xa0The Globe and Mail\r\n</li><li>B.C. child died of asthma attack made worse by wildfire smoke, parents say\xa0\xa0CBC News: The National\r\n</li><li>B.C. family says their nine-year-old died…", 'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMihgFodHRwczovL3d3dy50aGVnbG9iZWFuZG1haWwuY29tL2NhbmFkYS9icml0aXNoLWNvbHVtYmlhL2FydGljbGUtYmMtY29yb25lci1pc3N1ZXMtc2FmZXR5LWFsZXJ0LW92ZXItd2lsZGZpcmUtc21va2UtYWZ0ZXItY2hpbGRzLWRlYXRoL9IBAA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1', 'urlToImage': None, 'publishedAt': '2023-07-18T00:04:18Z', 'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'}
#
#
#
# Google News
# 2023-07-18
# BC Coroner issues safety alert over wildfire smoke after child s death The Globe and Mail
# BC Coroner issues safety alert over wildfire smoke after child s death The Globe and Mail
# Coroner issues safety alert over wildfire smoke after child death Globe Mail child died asthma attack made worse wildfire smoke parents News National family says their nine year died
# wildfire,2023-07-18,Google News,BC Coroner issues safety alert over wildfire smoke after child s death The Globe and Mail,Coroner issues safety alert over wildfire smoke after child death Globe Mail child died asthma attack made worse wildfire smoke parents News National family says their nine year died
#
# {'source': {'id': 'google-news', 'name': 'Google News'}, 'author': None, 'title': 'BC Emergency Alert: Evacuation Order for parts of Osoyoos and surrounding area due to wildfire. July 29, 2023. | EmergencyInfoBC - Emergency Info BC', 'description': '<ol><li>BC Emergency Alert: Evacuation Order for parts of Osoyoos and surrounding area due to wildfire. July 29, 2023. | EmergencyInfoBC\xa0\xa0Emergency Info BC\r\n</li><li>Evacuation order issued for parts of Osoyoos as growing wildfire crosses Canada-U.S. border\xa0\xa0…', 'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMiLmh0dHBzOi8vd3d3LmVtZXJnZW5jeWluZm9iYy5nb3YuYmMuY2EvMjlqdWwyMy_SAQA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1', 'urlToImage': None, 'publishedAt': '2023-07-30T15:00:38Z', 'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'}
#
#
#
# Google News
# 2023-07-30
# BC Emergency Alert Evacuation Order for parts of Osoyoos and surrounding area due to wildfire July EmergencyInfoBC Emergency Info BC
# BC Emergency Alert Evacuation Order for parts of Osoyoos and surrounding area due to wildfire July EmergencyInfoBC Emergency Info BC
# Emergency Alert Evacuation Order parts Osoyoos surrounding area wildfire July EmergencyInfoBC Emergency Info Evacuation order issued parts Osoyoos growing wildfire crosses Canada border
# wildfire,2023-07-30,Google News,BC Emergency Alert Evacuation Order for parts of Osoyoos and surrounding area due to wildfire July EmergencyInfoBC Emergency Info BC,Emergency Alert Evacuation Order parts Osoyoos surrounding area wildfire July EmergencyInfoBC Emergency Info Evacuation order issued parts Osoyoos growing wildfire crosses Canada border
#
# {'source': {'id': 'google-news', 'name': 'Google News'}, 'author': None, 'title': 'Wildfire that crossed U.S. border into B.C. pushed away by shifting winds - The Globe and Mail', 'description': '<ol><li>Wildfire that crossed U.S. border into B.C. pushed away by shifting winds\xa0\xa0The Globe and Mail\r\n</li><li>Global National: July 30, 2023 | Wildfire near Osoyoos forces hundreds to flee homes in BC\xa0\xa0Global News\r\n</li><li>Evacuation order issued for weste…', 'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMidWh0dHBzOi8vd3d3LnRoZWdsb2JlYW5kbWFpbC5jb20vY2FuYWRhL2FydGljbGUtd2lsZGZpcmUtdGhhdC1jcm9zc2VkLXVzLWJvcmRlci1pbnRvLWJjLXB1c2hlZC1hd2F5LWJ5LXNoaWZ0aW5nLXdpbmRzL9IBAA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1', 'urlToImage': None, 'publishedAt': '2023-07-31T01:27:38Z', 'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'}
#
#
#
# Google News
# 2023-07-31
# Wildfire that crossed U S border into B C pushed away by shifting winds The Globe and Mail
# Wildfire that crossed U S border into B C pushed away by shifting winds The Globe and Mail
# Wildfire that crossed border into pushed away shifting winds Globe Mail Global National July Wildfire near Osoyoos forces hundreds flee homes Global News Evacuation order issued weste
# wildfire,2023-07-31,Google News,Wildfire that crossed U S border into B C pushed away by shifting winds The Globe and Mail,Wildfire that crossed border into pushed away shifting winds Globe Mail Global National July Wildfire near Osoyoos forces hundreds flee homes Global News Evacuation order issued weste
#
# {'source': {'id': 'google-news', 'name': 'Google News'}, 'author': None, 'title': 'Wildfire evacuations: Boats provide only escape from B.C. lakefront community - CTV News Vancouver', 'description': '<ol><li>Wildfire evacuations: Boats provide only escape from B.C. lakefront community\xa0\xa0CTV News Vancouver\r\n</li><li>Ross Moore Lake wildfire inches closer to Lac Le Jeune\xa0\xa0Kamloops This Week\r\n</li><li>"Didn’t have to happen": Residents of evacuated BC communi…', 'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMie2h0dHBzOi8vYmMuY3R2bmV3cy5jYS9iLWMtd2lsZGZpcmVzLXNvbWUtcmVzaWRlbnRzLXJlZnVzZS10by1ldmFjdWF0ZS1sYWtlZnJvbnQtY29tbXVuaXR5LW9ubHktYWNjZXNzaWJsZS1ieS1ib2F0LTEuNjUwNjA3MNIBAA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1', 'urlToImage': None, 'publishedAt': '2023-08-03T22:15:56Z', 'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'}
#
#
#
# Google News
# 2023-08-03
# Wildfire evacuations Boats provide only escape from B C lakefront community CTV News Vancouver
# Wildfire evacuations Boats provide only escape from B C lakefront community CTV News Vancouver
# Wildfire evacuations Boats provide only escape from lakefront community News Vancouver Ross Moore Lake wildfire inches closer Jeune Kamloops This Week Didn have happen Residents evacuated communi
# wildfire,2023-08-03,Google News,Wildfire evacuations Boats provide only escape from B C lakefront community CTV News Vancouver,Wildfire evacuations Boats provide only escape from lakefront community News Vancouver Ross Moore Lake wildfire inches closer Jeune Kamloops This Week Didn have happen Residents evacuated communi
#
# {'source': {'id': 'google-news', 'name': 'Google News'}, 'author': None, 'title': 'Smoke visible from wildfire burning south of Summit Lake, near Nakusp - BC News - Castanet.net', 'description': '<ol><li>Smoke visible from wildfire burning south of Summit Lake, near Nakusp - BC News\xa0\xa0Castanet.net\r\n</li><li>Residents near Gun Lake, B.C., ordered to evacuate immediately due to growing wildfire north of Pemberton\xa0\xa0CBC.ca\r\n</li><li>Lac Le Jeune Provincial…', 'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMibGh0dHBzOi8vd3d3LmNhc3RhbmV0Lm5ldC9uZXdzL0JDLzQzOTcwNS9TbW9rZS12aXNpYmxlLWZyb20td2lsZGZpcmUtYnVybmluZy1zb3V0aC1vZi1TdW1taXQtTGFrZS1uZWFyLU5ha3VzcNIBAA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1', 'urlToImage': None, 'publishedAt': '2023-08-02T03:55:00Z', 'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'}
#
#
#
# Google News
# 2023-08-02
# Smoke visible from wildfire burning south of Summit Lake near Nakusp BC News Castanet net
# Smoke visible from wildfire burning south of Summit Lake near Nakusp BC News Castanet net
# Smoke visible from wildfire burning south Summit Lake near Nakusp News Castanet Residents near Lake ordered evacuate immediately growing wildfire north Pemberton Jeune Provincial
# wildfire,2023-08-02,Google News,Smoke visible from wildfire burning south of Summit Lake near Nakusp BC News Castanet net,Smoke visible from wildfire burning south Summit Lake near Nakusp News Castanet Residents near Lake ordered evacuate immediately growing wildfire north Pemberton Jeune Provincial
#
# {'source': {'id': 'google-news', 'name': 'Google News'}, 'author': None, 'title': 'Evacuation alert for 18 properties near wildfire north of Lake Okanagan Resort - West Kelowna News - Castanet.net', 'description': "<ol><li>Evacuation alert for 18 properties near wildfire north of Lake Okanagan Resort - West Kelowna News\xa0\xa0Castanet.net\r\n</li><li>Residents safely escape West Kelowna house fire\xa0\xa0Kelowna Capital News\r\n</li><li>Home burns in West Kelowna's Smith Creek - West …", 'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMigAFodHRwczovL3d3dy5jYXN0YW5ldC5uZXQvbmV3cy9XZXN0LUtlbG93bmEvNDM3MjUyL0V2YWN1YXRpb24tYWxlcnQtZm9yLTE4LXByb3BlcnRpZXMtbmVhci13aWxkZmlyZS1ub3J0aC1vZi1MYWtlLU9rYW5hZ2FuLVJlc29ydNIBAA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1', 'urlToImage': None, 'publishedAt': '2023-07-18T05:38:00Z', 'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'}
#
#
#
# Google News
# 2023-07-18
# Evacuation alert for properties near wildfire north of Lake Okanagan Resort West Kelowna News Castanet net
# Evacuation alert for properties near wildfire north of Lake Okanagan Resort West Kelowna News Castanet net
# Evacuation alert properties near wildfire north Lake Okanagan Resort West Kelowna News Castanet Residents safely escape West Kelowna house fire Kelowna Capital News Home burns West Kelowna Smith Creek West
# wildfire,2023-07-18,Google News,Evacuation alert for properties near wildfire north of Lake Okanagan Resort West Kelowna News Castanet net,Evacuation alert properties near wildfire north Lake Okanagan Resort West Kelowna News Castanet Residents safely escape West Kelowna house fire Kelowna Capital News Home burns West Kelowna Smith Creek West
#
# {'source': {'id': 'google-news', 'name': 'Google News'}, 'author': None, 'title': "Ash falls on Behchokǫ̀, Grand Chief says 'we need to get out' - Cabin Radio", 'description': '<ol><li>Ash falls on Behchokǫ̀, Grand Chief says \'we need to get out\'\xa0\xa0Cabin Radio\r\n</li><li>Responders had to \'flee\' Behchokǫ wildfire, extent of damage in community unclear\xa0\xa0CBC.ca\r\n</li><li>Evacuation Alert - Electoral Area "I" (Blue Sky Country) - Stein M…', 'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMid2h0dHBzOi8vY2FiaW5yYWRpby5jYS8xMzc0OTAvbmV3cy9lbnZpcm9ubWVudC93aWxkZmlyZXMvYXNoLWZhbGxzLW9uLWJlaGNob2slQzclQUItZ3JhbmQtY2hpZWYtc2F5cy13ZS1uZWVkLXRvLWdldC1vdXQv0gEA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1', 'urlToImage': None, 'publishedAt': '2023-07-26T11:23:09Z', 'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'}
#
#
#
# Google News
# 2023-07-26
# Ash falls on Behchok Grand Chief says we need to get out Cabin Radio
# Ash falls on Behchok Grand Chief says we need to get out Cabin Radio
# falls Behchok Grand Chief says need Cabin Radio Responders flee Behchok wildfire extent damage community unclear Evacuation Alert Electoral Area Blue Country Stein
# wildfire,2023-07-26,Google News,Ash falls on Behchok Grand Chief says we need to get out Cabin Radio,falls Behchok Grand Chief says need Cabin Radio Responders flee Behchok wildfire extent damage community unclear Evacuation Alert Electoral Area Blue Country Stein
#
# {'source': {'id': 'google-news', 'name': 'Google News'}, 'author': None, 'title': 'Emotional memorial held for Devyn Gale in Revelstoke, B.C. - CTV News Vancouver', 'description': "<ol><li>Emotional memorial held for Devyn Gale in Revelstoke, B.C.\xa0\xa0CTV News Vancouver\r\n</li><li>'Wherever you are Dev, I hope you can feel the love,' says brother during memorial for B.C. wildfire fighter\xa0\xa0CBC.ca\r\n</li><li>Memorial procession and service hel…", 'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMigQFodHRwczovL2JjLmN0dm5ld3MuY2Evc2hlLW1hZGUtbXktd29ybGQtc3BhcmtsZS1lbW90aW9uYWwtcHJvY2Vzc2lvbi1oZWxkLWZvci1mYWxsZW4tYi1jLXdpbGRmaXJlLWZpZ2h0ZXItaW4tcmV2ZWxzdG9rZS0xLjY0OTA1MjbSAQA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1', 'urlToImage': None, 'publishedAt': '2023-07-22T23:00:00Z', 'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'}
#
#
#
# Google News
# 2023-07-22
# Emotional memorial held for Devyn Gale in Revelstoke B C CTV News Vancouver
# Emotional memorial held for Devyn Gale in Revelstoke B C CTV News Vancouver
# Emotional memorial held Devyn Gale Revelstoke News Vancouver Wherever hope feel love says brother during memorial wildfire fighter Memorial procession service
# wildfire,2023-07-22,Google News,Emotional memorial held for Devyn Gale in Revelstoke B C CTV News Vancouver,Emotional memorial held Devyn Gale Revelstoke News Vancouver Wherever hope feel love says brother during memorial wildfire fighter Memorial procession service
#
# {'source': {'id': None, 'name': 'The Guardian'}, 'author': 'Guardian staff and agency', 'title': 'Huge wildfire explodes in southern California and spreads into Nevada', 'description': 'York fire, with zero containment Sunday evening, one of two major blazes burning in California as region faces hot and dry weatherA huge wildfire burning out of control in California’s Mojave national preserve is spreading rapidly amid erratic winds.The York …', 'url': 'https://www.theguardian.com/us-news/2023/jul/31/california-wildfire-mojave-york-fire', 'urlToImage': 'https://i.guim.co.uk/img/media/f76182b76330fbe54ab3509a0d935b4581aea1b9/0_273_8192_4918/master/8192.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=39e8065a2fa535ec4d33af1d3d578a1f', 'publishedAt': '2023-07-31T14:27:18Z', 'content': 'A huge wildfire burning out of control in Californias Mojave national preserve is spreading rapidly amid erratic winds.\r\nThe York fire erupted on Friday near the remote Caruthers Canyon area of the w… [+2506 chars]'}
#
#
#
# The Guardian
# 2023-07-31
# Huge wildfire explodes in southern California and spreads into Nevada
# Huge wildfire explodes in southern California and spreads into Nevada
# York fire with zero containment Sunday evening major blazes burning California region faces weatherA huge wildfire burning control California Mojave national preserve spreading rapidly amid erratic winds York
# wildfire,2023-07-31,The Guardian,Huge wildfire explodes in southern California and spreads into Nevada,York fire with zero containment Sunday evening major blazes burning California region faces weatherA huge wildfire burning control California Mojave national preserve spreading rapidly amid erratic winds York
#
# {'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': 'https://www.facebook.com/bbcnews', 'title': 'Young firefighter killed as Canada battles wildfires', 'description': 'Devyn Gale, 19, was struck by a falling tree while clearing brush near Revelstoke, British Columbia.', 'url': 'https://www.bbc.co.uk/news/world-us-canada-66209084', 'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/A7EC/production/_130388924_nolan.jpg', 'publishedAt': '2023-07-15T00:20:18Z', 'content': 'A 19-year-old firefighter has been killed in western Canada as the country battles its worst season of wildfires on record.\r\nDevyn Gale was struck by a falling tree while working in a remote area nea… [+2411 chars]'}
#
#
#
# BBC News
# 2023-07-15
# Young firefighter killed as Canada battles wildfires
# Young firefighter killed as Canada battles wildfires
# Devyn Gale struck falling tree while clearing brush near Revelstoke British Columbia
# wildfire,2023-07-15,BBC News,Young firefighter killed as Canada battles wildfires,Devyn Gale struck falling tree while clearing brush near Revelstoke British Columbia
#
# {'source': {'id': 'google-news', 'name': 'Google News'}, 'author': None, 'title': 'Wildfire on Greek island of Rhodes forces tourist evacuations - CTV News', 'description': 'Wildfire on Greek island of Rhodes forces tourist evacuations\xa0\xa0CTV NewsView Full Coverage on Google News', 'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMihAFodHRwczovL3d3dy5jdHZuZXdzLmNhL3dvcmxkL2Etd2lsZGZpcmUtaXMtcmFnaW5nLW91dC1vZi1jb250cm9sLW9uLXRoZS1ncmVlay1pc2xhbmQtb2YtcmhvZGVzLWZvcmNpbmctdG91cmlzdC1ldmFjdWF0aW9ucy0xLjY0OTAyOTbSAQA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1', 'urlToImage': None, 'publishedAt': '2023-07-22T18:24:01Z', 'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'}
#
#
#
# Google News
# 2023-07-22
# Wildfire on Greek island of Rhodes forces tourist evacuations CTV News
# Wildfire on Greek island of Rhodes forces tourist evacuations CTV News
# Wildfire Greek island Rhodes forces tourist evacuations NewsView Full Coverage Google News
# wildfire,2023-07-22,Google News,Wildfire on Greek island of Rhodes forces tourist evacuations CTV News,Wildfire Greek island Rhodes forces tourist evacuations NewsView Full Coverage Google News
#
# {'source': {'id': None, 'name': 'The Guardian'}, 'author': 'Guardian staff', 'title': 'Firefighters partially contain giant blaze in California’s Mojave desert', 'description': 'York fire mapped at 124 sq miles with 23% containment on Tuesday as Las Vegas strip saw smoky hazeFirefighters have managed to partially contain a giant wildfire in the Mojave desert that scorched tens of thousands of acres of scrub and sent smoke across the …', 'url': 'https://www.theguardian.com/us-news/2023/aug/01/california-wildfires-york-fire-mojave-desert-las-vegas', 'urlToImage': 'https://i.guim.co.uk/img/media/8bb2704934d42c456de6974a8aa17816299deebf/0_175_8192_4918/master/8192.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=fe7575c4e73a969a614ea74be5a7a5b5', 'publishedAt': '2023-08-01T15:16:28Z', 'content': 'Firefighters have managed to partially contain a giant wildfire in the Mojave desert that scorched tens of thousands of acres of scrub and sent smoke across the Las Vegas Strip.\r\nThe York fire was ma… [+7657 chars]'}
#
#
#
# The Guardian
# 2023-08-01
# Firefighters partially contain giant blaze in California s Mojave desert
# Firefighters partially contain giant blaze in California s Mojave desert
# York fire mapped miles with containment Tuesday Vegas strip smoky hazeFirefighters have managed partially contain giant wildfire Mojave desert that scorched tens thousands acres scrub sent smoke across
# wildfire,2023-08-01,The Guardian,Firefighters partially contain giant blaze in California s Mojave desert,York fire mapped miles with containment Tuesday Vegas strip smoky hazeFirefighters have managed partially contain giant wildfire Mojave desert that scorched tens thousands acres scrub sent smoke across
#
# {'source': {'id': 'google-news', 'name': 'Google News'}, 'author': None, 'title': 'Pilot dead after helicopter fighting wildfire crashes in northwestern Alberta - The Weather Network', 'description': 'Pilot dead after helicopter fighting wildfire crashes in northwestern Alberta\xa0\xa0The Weather NetworkView Full Coverage on Google News', 'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMihgFodHRwczovL3d3dy50aGV3ZWF0aGVybmV0d29yay5jb20vZW4vbmV3cy93ZWF0aGVyL3NldmVyZS9waWxvdC1kZWFkLWFmdGVyLWhlbGljb3B0ZXItZmlnaHRpbmctd2lsZGZpcmUtY3Jhc2hlcy1pbi1ub3J0aHdlc3Rlcm4tYWxiZXJ0YdIBAA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1', 'urlToImage': None, 'publishedAt': '2023-07-20T21:24:57Z', 'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'}
#
#
#
# Google News
# 2023-07-20
# Pilot dead after helicopter fighting wildfire crashes in northwestern Alberta The Weather Network
# Pilot dead after helicopter fighting wildfire crashes in northwestern Alberta The Weather Network
# Pilot dead after helicopter fighting wildfire crashes northwestern Alberta Weather NetworkView Full Coverage Google News
# wildfire,2023-07-20,Google News,Pilot dead after helicopter fighting wildfire crashes in northwestern Alberta The Weather Network,Pilot dead after helicopter fighting wildfire crashes northwestern Alberta Weather NetworkView Full Coverage Google News
#
# {'source': {'id': 'google-news', 'name': 'Google News'}, 'author': None, 'title': 'Residents in south-central B.C. ordered to evacuate. Only way out is by boat - The Weather Network', 'description': '<ol><li>Residents in south-central B.C. ordered to evacuate. Only way out is by boat\xa0\xa0The Weather Network\r\n</li><li>Aerial resources work southwest corner of Rossmoore Lake wildfire - Kamloops News\xa0\xa0Castanet Kamloops\r\n</li><li>New wildfire sparked near Enderb…', 'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMikwFodHRwczovL3d3dy50aGV3ZWF0aGVybmV0d29yay5jb20vZW4vbmV3cy93ZWF0aGVyL3NldmVyZS9yZXNpZGVudHMtaW4tc291dGgtY2VudHJhbC1iLWMtb3JkZXJlZC10by1ldmFjdWF0ZS1kdWUtdG8td2lsZGZpcmUtb25seS13YXktb3V0LWlzLWJ5LWJvYXTSAQA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1', 'urlToImage': None, 'publishedAt': '2023-08-03T13:50:00Z', 'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'}
#
#
#
# Google News
# 2023-08-03
# Residents in south central B C ordered to evacuate Only way out is by boat The Weather Network
# Residents in south central B C ordered to evacuate Only way out is by boat The Weather Network
# Residents south central ordered evacuate Only boat Weather Network Aerial resources work southwest corner Rossmoore Lake wildfire Kamloops News Castanet Kamloops wildfire sparked near Enderb
# wildfire,2023-08-03,Google News,Residents in south central B C ordered to evacuate Only way out is by boat The Weather Network,Residents south central ordered evacuate Only boat Weather Network Aerial resources work southwest corner Rossmoore Lake wildfire Kamloops News Castanet Kamloops wildfire sparked near Enderb
#
# ...
#
# {'source': {'id': None, 'name': 'Live Science'}, 'author': 'Aimee Gabay', 'title': 'Will the US run out of water?', 'description': '"The issue is not about running out of water, it\'s about having water in the right place," Lis Mullin Bernhardt, from the United Nations Environment Programme (UNEP), told Live Science.', 'url': 'https://www.livescience.com/planet-earth/climate-change/will-the-us-run-out-of-water', 'urlToImage': 'https://cdn.mos.cms.futurecdn.net/vSDuwRgRruEn4jEXQiFcw7-1200-80.jpg', 'publishedAt': '2023-08-01T09:33:40Z', 'content': "Within the next 50 years, many of the freshwater basins in the United States could struggle to meet the population's water demands\r\n.\r\nClimate change\r\n is causing severe droughts and greater aridity\r… [+5447 chars]"}
#
#
#
# Live Science
# 2023-08-01
# Will the US run out of water
# Will the US run out of water
# issue about running water about having water right place Mullin Bernhardt from United Nations Environment Programme UNEP told Live Science
# Droughts,2023-08-01,Live Science,Will the US run out of water,issue about running water about having water right place Mullin Bernhardt from United Nations Environment Programme UNEP told Live Science
#
# {'source': {'id': None, 'name': 'Psychology Today'}, 'author': 'La Keita D. Carter PsyD., LP', 'title': 'Could Scheduling Sex Kill My Relationship?', 'description': 'Planned intimacy may sound like a relationship killer, and it could be. It could also be a relationship saver.', 'url': 'https://www.psychologytoday.com/intl/blog/inside-intimacy/202307/could-scheduling-sex-kill-my-relationship', 'urlToImage': 'https://cdn2.psychologytoday.com/assets/styles/manual_crop_1_91_1_1528x800/public/teaser_image/blog_entry/2023-07/1.png.jpg?itok=Ca1Aj7m4', 'publishedAt': '2023-07-27T13:49:04Z', 'content': 'When a colleague told me to watch "Queen Charlotte," I was hesitant. Nonetheless, I turned it on while I was checking emails one afternoon. I was hooked by the opening scene (with Queen Charlotte and… [+3702 chars]'}
#
#
#
# Psychology Today
# 2023-07-27
# Could Scheduling Sex Kill My Relationship
# Could Scheduling Sex Kill My Relationship
# Planned intimacy sound like relationship killer could could also relationship saver
# Droughts,2023-07-27,Psychology Today,Could Scheduling Sex Kill My Relationship,Planned intimacy sound like relationship killer could could also relationship saver
#
# {'source': {'id': None, 'name': 'International Business Times'}, 'author': 'Valentin BONTEMPS', 'title': "Spain Worries Over 'Lifeless Land' Amid Creeping Desertification", 'description': 'Ongoing droughts and an over-exploitation of land for both agriculture and industry have stoked fears in Spain over the creeping spread of "sterile soil" which could devastate Europe\'s kitchen garden.', 'url': 'https://www.ibtimes.com/spain-worries-over-lifeless-land-amid-creeping-desertification-3707173', 'urlToImage': 'https://d.ibtimes.com/en/full/4477039/ruins-church-mediano-normally-submerged-waters-mediano-reservoir-are-now-visible-due.jpg', 'publishedAt': '2023-08-01T04:12:39Z', 'content': 'The ruins of the Church of Mediano, normally submerged in the waters of the Mediano reservoir, are now visible due to the ongoing droughtAFP\r\nOngoing droughts and an over-exploitation of land for bot… [+5018 chars]'}
#
#
#
# International Business Times
# 2023-08-01
# Spain Worries Over Lifeless Land Amid Creeping Desertification
# Spain Worries Over Lifeless Land Amid Creeping Desertification
# Ongoing droughts over exploitation land both agriculture industry have stoked fears Spain over creeping spread sterile soil which could devastate Europe kitchen garden
# Droughts,2023-08-01,International Business Times,Spain Worries Over Lifeless Land Amid Creeping Desertification,Ongoing droughts over exploitation land both agriculture industry have stoked fears Spain over creeping spread sterile soil which could devastate Europe kitchen garden
#
# {'source': {'id': None, 'name': 'The Guardian'}, 'author': 'Agencies in Algiers', 'title': 'Algeria wildfires kill dozens of people including 10 soldiers', 'description': 'About 7,500 firefighters trying to bring blazes under control and 1,500 people evacuates as heatwave hitsTen soldiers are among 25 people to have been killed by wildfires in the mountainous Béjaïa and Bouira regions of Algeria, as a heatwave spreads across no…', 'url': 'https://www.theguardian.com/world/2023/jul/24/algeria-wildfires-deaths-people-soldiers-heatwave', 'urlToImage': 'https://i.guim.co.uk/img/media/5b5bf462dfdcc1b3795ec0a9628ada149268e67b/0_772_1256_753/master/1256.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=01066cdfcb6ee7ed4784760040705bcf', 'publishedAt': '2023-07-24T16:57:18Z', 'content': 'Ten soldiers are among 25 people to have been killed by wildfires in the mountainous Béjaïa and Bouira regions of Algeria, as a heatwave spreads across north Africa and southern Europe.\r\nAbout 7,500 … [+2078 chars]'}
#
#
#
# The Guardian
# 2023-07-24
# Algeria wildfires kill dozens of people including soldiers
# Algeria wildfires kill dozens of people including soldiers
# About firefighters trying bring blazes under control people evacuates heatwave hitsTen soldiers among people have been killed wildfires mountainous Bouira regions Algeria heatwave spreads across
# Droughts,2023-07-24,The Guardian,Algeria wildfires kill dozens of people including soldiers,About firefighters trying bring blazes under control people evacuates heatwave hitsTen soldiers among people have been killed wildfires mountainous Bouira regions Algeria heatwave spreads across
#
# {'source': {'id': None, 'name': 'Forbes'}, 'author': 'GrrlScientist, Senior Contributor, \n GrrlScientist, Senior Contributor\n https://www.forbes.com/sites/grrlscientist/', 'title': 'Modern ‘Sixth Mass Extinction’ Event Will Be Worse Than First Predicted', 'description': 'The report argues that almost half of the planet’s animal species are now in decline, but unlike past mass extinctions, this one has been entirely caused by humans', 'url': 'https://www.forbes.com/sites/grrlscientist/2023/07/19/modern-sixth-mass-extinction-event-will-be-worse-than-first-predicted/', 'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/64b7e4ad8cabccd4effb68d3/0x0.jpg?format=jpg&crop=1646,927,x0,y500,safe&width=1200', 'publishedAt': '2023-07-19T21:20:50Z', 'content': 'The report argues that nearly half of the planets animal species are now in decline, but unlike past mass extinctions, this one has been entirely caused by humans\r\n© Copyright by GrrlScientist | host… [+6242 chars]'}
#
#
#
# Forbes
# 2023-07-19
# Modern Sixth Mass Extinction Event Will Be Worse Than First Predicted
# Modern Sixth Mass Extinction Event Will Be Worse Than First Predicted
# report argues that almost half planet animal species decline unlike past mass extinctions this been entirely caused humans
# Droughts,2023-07-19,Forbes,Modern Sixth Mass Extinction Event Will Be Worse Than First Predicted,report argues that almost half planet animal species decline unlike past mass extinctions this been entirely caused humans
#
# {'source': {'id': None, 'name': 'Forbes'}, 'author': 'Eva Amsen, Contributor, \n Eva Amsen, Contributor\n https://www.forbes.com/sites/evaamsen/', 'title': 'The Art Featured In This Year’s National Climate Assessment Report', 'description': 'Alongside an overview of the current science of climate change, the upcoming National Climate Assessment report will feature climate-inspired art.', 'url': 'https://www.forbes.com/sites/evaamsen/2023/07/27/the-art-featured-in-this-years-national-climate-assessment-report/', 'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/64c273fddb6010812703e3c3/0x0.jpg?format=jpg&crop=1943,1093,x0,y56,safe&width=1200', 'publishedAt': '2023-07-27T13:57:26Z', 'content': 'Every few years, the U.S. Global Change Research Program (USGCRP) releases the National Climate Assessment (NCA), which covers the current science of climate change, and an assessment of its impacts … [+5812 chars]'}
#
#
#
# Forbes
# 2023-07-27
# The Art Featured In This Year s National Climate Assessment Report
# The Art Featured In This Year s National Climate Assessment Report
# Alongside overview current science climate change upcoming National Climate Assessment report will feature climate inspired
# Droughts,2023-07-27,Forbes,The Art Featured In This Year s National Climate Assessment Report,Alongside overview current science climate change upcoming National Climate Assessment report will feature climate inspired
#
# {'source': {'id': None, 'name': 'Forbes'}, 'author': 'Jeff Opperman, Contributor, \n Jeff Opperman, Contributor\n https://www.forbes.com/sites/jeffopperman/', 'title': 'Rivers As Weapons Of War – And Warnings Of Climate Change (Part 2)', 'description': 'For millennia, armies have used rivers as weapons of war. While these were intentional disasters, they are the same ones that will become more likely with climate change.', 'url': 'https://www.forbes.com/sites/jeffopperman/2023/07/20/rivers-as-weapons-of-war--and-warnings-of-climate-change-part-2/', 'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/64b932346ed1911d73fb68d1/0x0.jpg?format=jpg&width=1200', 'publishedAt': '2023-07-20T13:53:42Z', 'content': 'Volunteers rescuing civilians in a flooded area in Kherson on June 8, 2023, following the breaching ... [+] of the Kakhovka Dam.\r\nAFP via Getty Images\r\nAlthough we often hear warnings that future war… [+5929 chars]'}
#
#
#
# Forbes
# 2023-07-20
# Rivers As Weapons Of War And Warnings Of Climate Change Part
# Rivers As Weapons Of War And Warnings Of Climate Change Part
# millennia armies have used rivers weapons While these were intentional disasters they same ones that will become more likely with climate change
# Droughts,2023-07-20,Forbes,Rivers As Weapons Of War And Warnings Of Climate Change Part,millennia armies have used rivers weapons While these were intentional disasters they same ones that will become more likely with climate change
#
# {'source': {'id': None, 'name': 'Science Daily'}, 'author': None, 'title': 'Climate science is catching up to climate change with predictions that could improve proactive response', 'description': 'In Africa, climate change impacts are experienced as extreme events like drought and floods. It has now been possible to predict and monitor these climatic events, providing early warning of their impacts on agriculture to support humanitarian and resilience …', 'url': 'https://www.sciencedaily.com/releases/2023/07/230721113141.htm', 'urlToImage': 'https://www.sciencedaily.com/images/scidaily-icon.png', 'publishedAt': '2023-07-21T15:31:41Z', 'content': 'In Africa, climate change impacts are experienced as extreme events like drought and floods. Through the Famine Early Warning Systems Network (which leverages expertise from USG science agencies, uni… [+6247 chars]'}
#
#
#
# Science Daily
# 2023-07-21
# Climate science is catching up to climate change with predictions that could improve proactive response
# Climate science is catching up to climate change with predictions that could improve proactive response
# Africa climate change impacts experienced extreme events like drought floods been possible predict monitor these climatic events providing early warning their impacts agriculture support humanitarian resilience
# Droughts,2023-07-21,Science Daily,Climate science is catching up to climate change with predictions that could improve proactive response,Africa climate change impacts experienced extreme events like drought floods been possible predict monitor these climatic events providing early warning their impacts agriculture support humanitarian resilience
#
# {'source': {'id': None, 'name': 'Home.blog'}, 'author': None, 'title': 'Loops and Arcs (2012)', 'description': 'Here are two tools I’ve been using lately to better understand the functionality of my game designs. \xa0The first is the loop, a structure that should be very familiar to those who have looked …', 'url': 'https://lostgarden.home.blog/2012/04/30/loops-and-arcs/', 'urlToImage': 'https://lostgardenhome.files.wordpress.com/2019/09/20148-gameatoms_loop.png', 'publishedAt': '2023-07-15T03:54:09Z', 'content': 'Here are two tools I’ve been using lately to better understand the functionality of my game designs. \xa0The first is the loop, a structure that should be very familiar to those who have looked into ski… [+14964 chars]'}
#
#
#
# Home.blog
# 2023-07-15
# Loops and Arcs
# Loops and Arcs
# Here tools been using lately better understand functionality game designs first loop structure that should very familiar those have looked
# Droughts,2023-07-15,Home.blog,Loops and Arcs,Here tools been using lately better understand functionality game designs first loop structure that should very familiar those have looked
#
# {'source': {'id': None, 'name': 'Phys.Org'}, 'author': 'Abdellah Cheballah', 'title': 'Algeria fires fanned by winds, extreme heat kill 34', 'description': 'Wildfires raging across Algeria during a blistering heat wave have killed more than 30 people and forced mass evacuations, the government said on Monday.', 'url': 'https://phys.org/news/2023-07-algeria-fanned-extreme.html', 'urlToImage': 'https://scx2.b-cdn.net/gfx/news/2023/algeria-has-mobilised.jpg', 'publishedAt': '2023-07-24T20:00:01Z', 'content': 'Wildfires raging across Algeria during a blistering heat wave have killed more than 30 people and forced mass evacuations, the government said on Monday.\r\nAs temperatures hit 48 degrees Celsius (118 … [+4160 chars]'}
#
#
#
# Phys.Org
# 2023-07-24
# Algeria fires fanned by winds extreme heat kill
# Algeria fires fanned by winds extreme heat kill
# Wildfires raging across Algeria during blistering heat wave have killed more than people forced mass evacuations government said Monday
# Droughts,2023-07-24,Phys.Org,Algeria fires fanned by winds extreme heat kill,Wildfires raging across Algeria during blistering heat wave have killed more than people forced mass evacuations government said Monday
#
# {'source': {'id': None, 'name': 'Phys.Org'}, 'author': 'Science X', 'title': 'Geostationary satellite reveals widespread midday depression in dryland photosynthesis during 2020 heat wave', 'description': 'The western U.S., particularly the Southwest, has experienced a notable increase in record-breaking high temperatures over recent decades, with recurring drought and heat waves. These conditions have resulted in severe consequences for both human and nature s…', 'url': 'https://phys.org/news/2023-08-geostationary-satellite-reveals-widespread-midday.html', 'urlToImage': 'https://scx2.b-cdn.net/gfx/news/hires/2021/heat-wave.jpg', 'publishedAt': '2023-08-03T14:07:03Z', 'content': 'The western U.S., particularly the Southwest, has experienced a notable increase in record-breaking high temperatures over recent decades, with recurring drought and heat waves. These conditions have… [+5841 chars]'}
#
#
#
# Phys.Org
# 2023-08-03
# Geostationary satellite reveals widespread midday depression in dryland photosynthesis during heat wave
# Geostationary satellite reveals widespread midday depression in dryland photosynthesis during heat wave
# western particularly Southwest experienced notable increase record breaking high temperatures over recent decades with recurring drought heat waves These conditions have resulted severe consequences both human nature
# Droughts,2023-08-03,Phys.Org,Geostationary satellite reveals widespread midday depression in dryland photosynthesis during heat wave,western particularly Southwest experienced notable increase record breaking high temperatures over recent decades with recurring drought heat waves These conditions have resulted severe consequences both human nature
